# %% [markdown]
# <a href="https://colab.research.google.com/github/rampravesh80/Dataset-for-Fire-Firearm/blob/main/Yolov11_Trained_on_firerams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install ultralytics
# !pip install ultralytics

from ultralytics import YOLO

# %%
# Load your model (pretrained or custom)
model = YOLO('/content/best.pt')  # Example: 'yolov8n.pt' or your trained weights
# Run prediction on a video
results = model.predict(
    source='/content/degraded_video_2.mp4',  # Can be a local file or a URL
    show=True,      # Displays the video with detections live in Colab output
    save=True,      # Saves the output video
    conf=0.5        # Confidence threshold
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/613) /content/degraded_video_2.mp4: 480x640 (no detections), 998.9ms
# video 1/1 (frame 2/613) /content/degraded_video_2.mp4: 480x640 (no detections), 935.8ms
# video 1/1 (frame 3/613) /content/degraded_video_2.mp4: 480x640 (no detections), 929.0ms
# video 1/1 (frame 4/613) /content/degraded_video_2.mp4: 480x640 (no detections), 1181.3ms
# ...

# %%
# Run prediction on an image
results = model.predict(source='Test_video_1.mp4', save=True, conf=0.5)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/234) /content/Test_video_1.mp4: 640x384 1 person, 256.0ms
# video 1/1 (frame 2/234) /content/Test_video_1.mp4: 640x384 1 person, 225.6ms
# video 1/1 (frame 3/234) /content/Test_video_1.mp4: 640x384 1 person, 177.6ms
# video 1/1 (frame 4/234) /content/Test_video_1.mp4: 640x384 1 person, 176.8ms
# video 1/1 (frame 5/234) /content/Test_video_1.mp4: 640x384 1 person, 1 bed, 156.2ms
# ...

# %%
model_1 = YOLO('/content/weights/hub/7wzkDSKNMcwkPTs8ZVJC/best.pt')
results = model.predict(source='handgun_image_33.jpg', save=True, conf=0.5)
# Out:
# image 1/1 /content/handgun_image_33.jpg: 640x640 1 person, 246.8ms
# Speed: 3.5ms preprocess, 246.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
